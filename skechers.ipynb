# %%
# !pip install bs4
# !pip install requests
# Out:
# Requirement already satisfied: bs4 in c:\users\akash\anaconda3\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\akash\anaconda3\lib\site-packages (from bs4) (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\akash\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.4)
# Requirement already satisfied: requests in c:\users\akash\anaconda3\lib\site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\akash\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\akash\anaconda3\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\akash\anaconda3\lib\site-packages (from requests) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\akash\anaconda3\lib\site-packages (from requests) (2023.7.22)

# %%
from bs4 import BeautifulSoup
import requests

# %%
page = requests.get('https://www.skechers.com')

# %%
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html class="g-local-en_US" lang="en">
# <head>
# <!--[if gt IE 9]><!-->
# <script>
#     (function () {
#
#
#         /**
#          * Prevent default for links containing class `js-ignore-click`
#          * @param {Event} e
#          */
#         var clickListener = function (e) {
#             if (
#                 e &&
#                 e.target &&
#                 e.target.classList &&
#                 e.target.classList.contains('js-ignore-click')
#             ) {
#                 e.preventDefault();
#             }
#         }
#
#         /**
#          * Remove click listener then remove itself from `app:JsLoaded` listener.
#          */
#         var appJsLoadedListener = function () {
#             document.removeEventListener('click', clickListener)
#             document.removeEventListener('app:JsLoaded', appJsLoadedListener);
#         };
#
#         document.addEventListener('click', clickListener);
#         document.addEventListener('app:JsLoaded', appJsLoadedListener);
#     }());
# </script>
# <script>
#     document.addEventListener('DOMContentLoaded', function () {
#         var url = "https://www.skechers.com/on/demandware.store/Sites-USSkechers-Site/en_US/Geolocation-SetGeolocation?fromAction=Sites-USSkechers-Site";
#
#         // Send geolocation to SFCC
#         function success(position) {
#             var pid = $('.product-detail[data-pid]').data('pid');
#
#             $.ajax({
#                 url: url,
#                 method: 'GET',
#                 data: {
#                     latitude: position.coords.latitude,
#                     longitude: position.coords.longitude,
#                     pid: pid
#                 },
#                 success: function (data) {
#                     // run the header logic
#                     // Update the Class
#
#                     var $containerHeader = $('.js-global-header');
#
#                         $('body').trigger('instore:updateStoreHeader', {
#                             data: data,
#                             container: $containerHeader
#                         });
#
#
#
#                 },
#                 error: function (err) {
#                 }
#             });
#         }
#
#         // Sets an error flag so multiple geolocation requests aren't made
#         function error(err) {
#             var url = "https://www.skechers.com/on/demandware.store/Sites-USSkechers-Site/en_US/Geolocation-SetGeolocation?fromAction=Sites-USSkechers-Site";
#
#             $.ajax({
#                 url: url,
#                 method: 'GET',
#                 data: {
#                     error: 'true'
#                 },
#                 success: function (data) {
#                 },
#                 error: function (err) {
#                 }
#             })
#         }
#
#         navigator.geolocation.getCurrentPosition(success, error);
#     });
# </script>
# <script>
#     (function() {
#         window.dataLayer = window.dataLayer || [];
#
#
#
#         window.dataLayer.push({"event":"pageview","page":{"type":"home"},"user":{"id":"","loggedIn":false,"hashedemail":"","locale":"en_US"},"site":{"environment":"production"}});
#
#         window.dataLayer.push({"user":{"loggedIn":"false"}});
#
#
#     }());
# </script>
# <script>
#     (function() {
#         window.dataLayer = window.dataLayer || [];
#
#
#
#         window.dataLayer.push({"pageType":"home"});
#
#         window.dataLayer.push({"ecomm_pagetype":"home"});
#
#         window.dataLayer.push({"page":{"currencyCode":"USD","locale":"en_US","pageTitle":"SKECHERS Official Site | The Comfort Technology Company","pageType":"Home"}});
#
#
#     }());
# </script>
# <script>
#    vice= {
#         config: {
#             viceAccountId: 'skecherssecurity',
#             viceSiteId: 'skechers',
#             viceSectionId: ''
#         }
#     }
# </script>
# <script src="//assets.skechers.com/skccdn/vice_loader/skecherssecurity/skechers"></script>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl+ '&gtm_auth=7lRL-CECKNSv2w3ulidcfw&gtm_preview=env-1&gtm_cookies_win=x';f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-TDRBQZ');</script>
# <script>//common/scripts.isml</script>
# <script defer="" src="https://www.skechers.com/on/demandware.static/Sites-USSkechers-Site/-/en_US/v1702916928659/js/main.js" type="text/javascript"></script>
# <script defer="" src="https://www.skechers.com/on/demandware.static/Sites-USSkechers-Site/-/en_US/v1702916928659/js/sfra.js" type="text/javascript"></script>
# <script defer="" src="/on/demandware.static/Sites-USSkechers-Site/-/en_US/v1702916928659/js/login.js" type="text/javascript">
# </script>
# <script>
# var CRL8_SITENAME = "skechers-9cenl4";
# window.loadCuralate = function () {
#     if (document.getElementById('js-load-curalate')) {
#         !function(){var e=window.crl8=window.crl8||{},n=!1,i=[];e.ready=function(e){n?e():i.push(e)},e.pixel=e.pixel||function(){e.pixel.q.push(arguments)},e.pixel.q=e.pixel.q||[];var t=window.document,o=t.createElement("script"),c=e.debug||-1!==t.location.search.indexOf("crl8-debug=true")?"js":"min.js";o.src=t.location.protocol+"//cdn.curalate.com/sites/"+CRL8_SITENAME+"/site/latest/site."+c,o.onload=function(){n=!0,i.forEach(function(e){e()})};var r=t.getElementsByTagName("script")[0];r.parentNode.insertBefore(o,r.nextSibling)}();
#     }
# };
# </script>
# <!--<![endif]-->
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <script>
#
#     var root = document.documentElement;
#     root.className = (root.className + ' js').trim();
#     if (document.cookie.length) {
#         root.className = (root.className + ' cookie').trim();
#     }
#
#
#     WebFontConfig = {
#         google: {
#             families: [
#                 'Mulish:300,400,500,600,700,800&display=swap'
#             ]
#         },
#         timeout: 2000
#     };
#    (function(d) {
#         var wf = d.createElement('script'), s = d.scripts[0];
#         wf.src = 'https://cdnjs.cloudflare.com/ajax/libs/webfont/1.6.28/webfontloader.js';
#         wf.async = true;
#         s.parentNode.insertBefore(wf, s);
#    })(document);
# </script>
# <title>SKECHERS Official Site | The Comfort Technology Company</title>
# <meta content="Lifestyle and athletic footwear and apparel for men, women, and kids filled with innovative comfort technologies. Free Shipping &amp;amp; more with Skechers Plus" name="description"/>
# <meta content="https://www.skechers.com/on/demandware.static/Sites-USSkechers-Site/-/default/images/skechers_logo.png" property="og:image"/>
# <meta content="156622481018682" property="fb:app_id"/>
# <meta content="500" property="og:image:width"/>
# <meta content="website" property="og:type"/>
# <meta content="SKECHERS US" property="og:site_name"/>
# <meta content="Lifestyle and athletic footwear and apparel for men, women, and kids filled with innovative comfort technologies." property="og:title"/>
# <meta content="500" property="og:image:height"/>
# <meta content="https://www.skechers.com/" property="og:url"/>
# <link href="https://www.skechers.com/" rel="canonical"/>
# <link href="https://www.skechers.com/" hreflang="x-default" rel="alternate"/>
# <link href="https://www.skechers.jp/" hreflang="ja-jp" rel="alternate"/>
# <link href="https://www.skechers.jp/en" hreflang="en-jp" rel="alternate"/>
# <link href="https://www.skechers.at/en" hreflang="en-at" rel="alternate"/>
# <link href="https://www.skechers.at/" hreflang="de-at" rel="alternate"/>
# <link href="https://www.skechers.be/" hreflang="nl-be" rel="alternate"/>
# <link href="https://www.skechers.be/fr" hreflang="fr-be" rel="alternate"/>
# <link href="https://www.skechers.be/en" hreflang="en-be" rel="alternate"/>
# <link href="https://www.skechers.ch/" hreflang="de-ch" rel="alternate"/>
# <link href="https://www.skechers.ch/it" hreflang="it-ch" rel="alternate"/>
# <link href="https://www.skechers.ch/fr" hreflang="fr-ch" rel="alternate"/>
# <link href="https://www.skechers.ch/en" hreflang="en-ch" rel="alternate"/>
# <link href="https://www.skechers.cz/en" hreflang="en-cz" rel="alternate"/>
# <link href="https://www.skechers.cz/" hreflang="cs-cz" rel="alternate"/>
# <link href="https://www.skechers.de/" hreflang="de-de" rel="alternate"/>
# <link href="https://www.skechers.de/en" hreflang="en-de" rel="alternate"/>
# <link href="https://www.skechers.es/" hreflang="es-es" rel="alternate"/>
# <link href="https://www.skechers.es/en" hreflang="en-es" rel="alternate"/>
# <link href="https://www.skechers.fr/en" hreflang="en-fr" rel="alternate"/>
# <link href="https://www.skechers.fr/" hreflang="fr-fr" rel="alternate"/>
# <link href="https://www.skechers.hu/en" hreflang="en-hu" rel="alternate"/>
# <link href="https://www.skechers.hu/" hreflang="hu-hu" rel="alternate"/>
# <link href="https://www.skechers.ie/" hreflang="en-ie" rel="alternate"/>
# <link href="https://www.skechers.it/en" hreflang="en-it" rel="alternate"/>
# <link href="https://www.skechers.it/" hreflang="it-it" rel="alternate"/>
# <link href="https://www.skechers.nl/" hreflang="nl-nl" rel="alternate"/>
# <link href="https://www.skechers.nl/en" hreflang="en-nl" rel="alternate"/>
# <link href="https://www.skechers.pl/en" hreflang="en-pl" rel="alternate"/>
# <link href="https://www.skechers.pl/" hreflang="pl-pl" rel="alternate"/>
# <link href="https://www.skechers.pt/" hreflang="pt-pt" rel="alternate"/>
# <link href="https://www.skechers.pt/en" hreflang="en-pt" rel="alternate"/>
# <link href="https://www.skechers.co.uk/" hreflang="en-gb" rel="alternate"/>
# <link href="https://www.skechers.ca/en/homepage/" hreflang="en-ca" rel="alternate"/>
# <link href="https://www.skechers.ca/fr/pagedaccueil/" hreflang="fr-ca" rel="alternate"/>
# <link href="https://www.skechers.com/" hreflang="en-us" rel="alternate"/>
# <link href="https://www.skechers.com/on/demandware.static/Sites-USSkechers-Site/-/default/dw81a1269d/images/favicons/apple-touch-icon.png" rel="apple-touch-icon"/>
# <link href="https://www.skechers.com/on/demandware.static/Sites-USSkechers-Site/-/default/dw5e991196/images/favicons/favicon-32x32.png" rel="icon" type="image/png"/>
# <link href="https://www.skechers.com/on/demandware.static/Sites-USSkechers-Site/-/default/dw203aa6d7/images/favicons/favicon-16x16.png" rel="icon" type="image/png"/>
# <link href="https://www.skechers.com/on/demandware.static/Sites-USSkechers-Site/-/default/dw3b428b13/images/favicons/favicon.ico" rel="shortcut icon" type="image/png"/>
# <link href="https://www.skechers.com/on/demandware.static/Sites-USSkechers-Site/-/default/dwed240044/images/favicons/site.webmanifest" rel="manifest"/>
# <script>
#     window.addEventListener('load', (event) => {
#
#             const _link0 = document.createElement('link');
#             _link0.setAttribute('rel', 'stylesheet');
#             _link0.setAttribute('href', 'https://www.skechers.com/on/demandware.static/Sites-USSkechers-Site/-/en_US/v1702916928659/css/scopes/s-reflektion-simple.css');
#
#             document.head.appendChild(_link0);
#
#
#
#             const _jsSrc0 = document.createElement('script');
#             _jsSrc0.setAttribute('src', 'https://www.skechers.com/on/demandware.static/Sites-USSkechers-Site/-/en_US/v1702916928659/js/trackOrder.js');
#             document.head.appendChild(_jsSrc0);
#
#     });
# </script>
# <link href="https://www.skechers.com/on/demandware.static/Sites-USSkechers-Site/-/en_US/v1702916928659/css/global.css" rel="stylesheet"/>
# <link href="/on/demandware.static/Sites-USSkechers-Site/-/en_US/v1702916928659/css/page-designer.css" rel="stylesheet"/>
# <link href="/on/demandware.static/Sites-USSkechers-Site/-/en_US/v1702916928659/css/login.css" rel="stylesheet"/>
# <meta content="VMacYSQs3JVVUUXPnDNuNACc4m2-YbDdjKtVyV4IpLI" name="google-site-verification"/>
# <script type="text/javascript">//<!--
# /* <![CDATA[ (head-active_data.js) */
# var dw = (window.dw || {});
# dw.ac = {
#     _analytics: null,
#     _events: [],
#     _category: "",
#     _searchData: "",
#     _anact: "",
#     _anact_nohit_tag: "",
#     _analytics_enabled: "true",
#     _timeZone: "America/Los_Angeles",
#     _capture: function(configs) {
#         if (Object.prototype.toString.call(configs) === "[object Array]") {
#             configs.forEach(captureObject);
#             return;
#         }
#         dw.ac._events.push(configs);
#     },
# 	capture: function() {
# 		dw.ac._capture(arguments);
# 		// send to CQ as well:
# 		if (window.CQuotient) {
# 			window.CQuotient.trackEventsFromAC(arguments);
# 		}
# 	},
#     EV_PRD_SEARCHHIT: "searchhit",
#     EV_PRD_DETAIL: "detail",
#     EV_PRD_RECOMMENDATION: "recommendation",
#     EV_PRD_SETPRODUCT: "setproduct",
#     applyContext: function(context) {
#         if (typeof context === "object" && context.hasOwnProperty("category")) {
#         	dw.ac._category = context.category;
#         }
#         if (typeof context === "object" && context.hasOwnProperty("searchData")) {
#         	dw.ac._searchData = context.searchData;
#         }
#     },
#     setDWAnalytics: function(analytics) {
#         dw.ac._analytics = analytics;
#     },
#     eventsIsEmpty: function() {
#         return 0 == dw.ac._events.length;
#     }
# };
# /* ]]> */
# // -->
# </script>
# <script type="text/javascript">//<!--
# /* <![CDATA[ (head-cquotient.js) */
# var CQuotient = window.CQuotient = {};
# CQuotient.clientId = 'bdcn-USSkechers';
# CQuotient.realm = 'BDCN';
# CQuotient.siteId = 'USSkechers';
# CQuotient.instanceType = 'prd';
# CQuotient.locale = 'en_US';
# CQuotient.fbPixelId = '__UNKNOWN__';
# CQuotient.activities = [];
# CQuotient.cqcid='';
# CQuotient.cquid='';
# CQuotient.cqeid='';
# CQuotient.cqlid='';
# CQuotient.apiHost='api.cquotient.com';
# /* Turn this on to test against Staging Einstein */
# /* CQuotient.useTest= true; */
# CQuotient.useTest = ('true' === 'false');
# CQuotient.initFromCookies = function () {
# 	var ca = document.cookie.split(';');
# 	for(var i=0;i < ca.length;i++) {
# 	  var c = ca[i];
# 	  while (c.charAt(0)==' ') c = c.substring(1,c.length);
# 	  if (c.indexOf('cqcid=') == 0) {
# 		CQuotient.cqcid=c.substring('cqcid='.length,c.length);
# 	  } else if (c.indexOf('cquid=') == 0) {
# 		  var value = c.substring('cquid='.length,c.length);
# 		  if (value) {
# 		  	var split_value = value.split("|", 3);
# 		  	if (split_value.length > 0) {
# 			  CQuotient.cquid=split_value[0];
# 		  	}
# 		  	if (split_value.length > 1) {
# 			  CQuotient.cqeid=split_value[1];
# 		  	}
# 		  	if (split_value.length > 2) {
# 			  CQuotient.cqlid=split_value[2];
# 		  	}
# 		  }
# 	  }
# 	}
# }
# CQuotient.getCQCookieId = function () {
# 	if(window.CQuotient.cqcid == '')
# 		window.CQuotient.initFromCookies();
# 	return window.CQuotient.cqcid;
# };
# CQuotient.getCQUserId = function () {
# 	if(window.CQuotient.cquid == '')
# 		window.CQuotient.initFromCookies();
# 	return window.CQuotient.cquid;
# };
# CQuotient.getCQHashedEmail = function () {
# 	if(window.CQuotient.cqeid == '')
# 		window.CQuotient.initFromCookies();
# 	return window.CQuotient.cqeid;
# };
# CQuotient.getCQHashedLogin = function () {
# 	if(window.CQuotient.cqlid == '')
# 		window.CQuotient.initFromCookies();
# 	return window.CQuotient.cqlid;
# };
# CQuotient.trackEventsFromAC = function (/* Object or Array */ events) {
# try {
# 	if (Object.prototype.toString.call(events) === "[object Array]") {
# 		events.forEach(_trackASingleCQEvent);
# 	} else {
# 		CQuotient._trackASingleCQEvent(events);
# 	}
# } catch(err) {}
# };
# CQuotient._trackASingleCQEvent = function ( /* Object */ event) {
# 	if (event && event.id) {
# 		if (event.type === dw.ac.EV_PRD_DETAIL) {
# 			CQuotient.trackViewProduct( {id:'', alt_id: event.id, type: 'raw_sku'} );
# 		} // not handling the other dw.ac.* events currently
# 	}
# };
# CQuotient.trackViewProduct = function(/* Object */ cqParamData){
# 	var cq_params = {};
# 	cq_params.cookieId = CQuotient.getCQCookieId();
# 	cq_params.userId = CQuotient.getCQUserId();
# 	cq_params.emailId = CQuotient.getCQHashedEmail();
# 	cq_params.loginId = CQuotient.getCQHashedLogin();
# 	cq_params.product = cqParamData.product;
# 	cq_params.realm = cqParamData.realm;
# 	cq_params.siteId = cqParamData.siteId;
# 	cq_params.instanceType = cqParamData.instanceType;
# 	cq_params.locale = CQuotient.locale;
#
# 	if(CQuotient.sendActivity) {
# 		CQuotient.sendActivity(CQuotient.clientId, 'viewProduct', cq_params);
# 	} else {
# 		CQuotient.activities.push({activityType: 'viewProduct', parameters: cq_params});
# 	}
# };
# /* ]]> */
# // -->
# </script>
# <style type="text/css">ISAPPLEPAY{display:inline}.dw-apple-pay-button,.dw-apple-pay-button:hover,.dw-apple-pay-button:active{background-color:black;background-image:-webkit-named-image(apple-pay-logo-white);background-position:50% 50%;background-repeat:no-repeat;background-size:75% 60%;border-radius:5px;border:1px solid black;box-sizing:border-box;margin:5px auto;min-height:30px;min-width:100px;padding:0}
# .dw-apple-pay-button:after{content:'Apple Pay';visibility:hidden}.dw-apple-pay-button.dw-apple-pay-logo-white{background-color:white;border-color:white;background-image:-webkit-named-image(apple-pay-logo-black);color:black}.dw-apple-pay-button.dw-apple-pay-logo-white.dw-apple-pay-border{border-color:black}</style>
# </head><body><div class="content-asset contentasset--seo-organization-schema">
# <script type="application/ld+json">
# {
#   "@context": "https://schema.org",
#   "@type": "Organization",
#   "name": "Skechers",
#   "alternateName": "Skechers USA, Inc.",
#   "url": "https://www.skechers.com",
#   "logo": "https://www.skechers.com/on/demandware.static/Sites-USSkechers-Site/-/default/images/skechers_logo.png",
#   "contactPoint": {
#     "@type": "ContactPoint",
#     "telephone": "1 (800) 746-3411",
#     "contactType": "customer service",
#     "contactOption": "TollFree",
#     "areaServed": "US",
#     "availableLanguage": "en"
#   },
#   "sameAs": [
#     "https://www.facebook.com/SKECHERS",
#     "https://twitter.com/SKECHERSUSA",
#     "https://www.instagram.com/skechers/",
#     "https://www.linkedin.com/company/skechers",
#     "https://www.youtube.com/user/SKECHERS",
#     "https://en.wikipedia.org/wiki/Skechers",
#     "https://www.pinterest.com/skechers/"
#   ]
# }
# </script>
# </div>
# <script type="application/ld+json">
#         {"@context":"https://schema.org","@type":"WebSite","url":"https://www.skechers.com/","potentialAction":{"@type":"SearchAction","target":{"@type":"EntryPoint","urlTemplate":"https://www.skechers.com/search/?q={search_term_string}"},"query-input":"required name=search_term_string"}}
#     </script>
# <script type="text/javascript">
#         (function () {
#             window._pxAppId = 'PXdL6GOSf9';
#             // Custom parameters
#             // window._pxParam1 = "<param1>";
#             var p = document.getElementsByTagName('script')[0],
#                 s = document.createElement('script');
#             s.async = 1;
#             s.src = '/dL6GOSf9/init.js';
#             p.parentNode.insertBefore(s, p);
#         }());
#     </script>
# <div class="page" data-action="Sites-USSkechers-Site" data-querystring="">
# <div class="contentasset--skinny-banner-BOPAC-sale" id="campaign-skinny-banner">
# <div class="deal">
# <span class="desktop-only">Holiday Shopping Spree! <a href="https://www.skechers.com/login/">25% OFF for Members</a></span>
# <span class="mobile-only"><a href="https://www.skechers.com/login/">25% OFF for Members</a></span>
# Code: <span class="promo-code">FESTIVE</span>
# <a href="https://www.skechers.com/m/promo-details/" id="campaign-banner-cta">details</a>
# </div>
# </div>
# <header class="c-header-global js-global-header">
# <a aria-label="Skip to main content" class="skip" href="#maincontent">Skip to main content</a>
# <a aria-label="Skip to footer content" class="skip" href="#footercontent">Skip to footer content</a>
# <nav class="c-header-global__navigation__secondary">
# <div class="header container-fluid js-header-nav-secondary">
# <div class="row">
# <div class="col-12 d-none d-lg-block">
# <div class="d-lg-flex justify-content-end">
# <div class="c-header-global__navigation__secondary__item">
# <div class="user hidden-md-down c-header-global__loyalty-nav-container js-loyalty-nav-container">
# <a aria-label="Login to your account" class="c-header-global__navigation__secondary__item__link loyalty-nav-link js-loyalty-nav-link" href="https://www.skechers.com/login/" id="utility-login" role="button">
# <svg aria-hidden="true" class="c-icon--account">
# <title class="sr-only" font-size="0" x="50%" y="50%">Login</title>
# <use class="" xlink:href="https://www.skechers.com/on/demandware.static/Sites-USSkechers-Site/-/default/dw1a66e44c/svg/symbols.svg#svg-account"></use>
# <text class="sr-only" font-size="0" x="50%" y="50%">Login</text>
# </svg>
# <span class="user-message">Login</span>
# </a>
# <div class="c-header-global__loyalty-nav js-loyalty-nav">
# <div class="c-header-global__loyalty-nav-body">
# <svg aria-hidden="true" class="c-icon--logo-plus">
# <title class="sr-only" font-size="0" x="50%" y="50%">Skechers Plus</title>
# <use class="" xlink:href="https://www.skechers.com/on/demandware.static/Sites-USSkechers-Site/-/default/dw1a66e44c/svg/symbols.svg#svg-logo-skechers-plus"></use>
# <text class="sr-only" font-size="0" x="50%" y="50%">Skechers Plus</text>
# </svg>
# <p>Log in for <b>Free Shipping</b> on all orders!</p>
# <div class="c-header-global__loyalty-nav-action">
# <a class="btn btn-primary" href="https://www.skechers.com/login/?rurl=3" role="button">Log in</a>
# <a class="btn btn-outline-secondary" href="https://www.skechers.com/login/?action=register" role="button">Join</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="c-header-global__navigation__secondary__item">
# <a class="c-header-global__navigation__secondary__item__link js-recaptcha-modal" data-form="order-lookup" data-url="https://www.skechers.com/on/demandware.store/Sites-USSkechers-Site/en_US/Order-Track?renderModal=true" href="https://www.skechers.com/on/demandware.store/Sites-USSkechers-Site/en_US/Order-Track" id="utility-orders-returns">
# <svg aria-hidden="true" class="c-icon--truck">
# <use class="" xlink:href="https://www.skechers.com/on/demandware.static/Sites-USSkechers-Site/-/default/dw1a66e44c/svg/symbols.svg#svg-truck"></use>
# </svg>
# Orders &amp; Returns
# </a>
# </div>
# <div class="c-header-global__navigation__secondary__item">
# <a class="c-header-global__navigation__secondary__item__link store-locator" href="https://www.skechers.com/store-locator.html" id="utility-stores" title="Locate Stores">
# <svg aria-hidden="true" class="c-icon--store-locator-desktop">
# <use class="" xlink:href="https://www.skechers.com/on/demandware.static/Sites-USSkechers-Site/-/default/dw1a66e44c/svg/symbols.svg#svg-store-locator-desktop"></use>
# </svg>
# Stores
# </a>
# </div>
# <div class="c-header-global__navigation__secondary__item">
# <a class="c-header-global__navigation__secondary__item__link" href="https://www.skechers.com/help-center.html" id="utility-help">
# <svg aria-hidden="true" class="c-icon--help">
# <use class="" xlink:href="https://www.skechers.com/on/demandware.static/Sites-USSkechers-Site/-/default/dw1a66e44c/svg/symbols.svg#svg-help"></use>
# </svg>
# Help
# </a>
# </div>
# <div class="c-header-global__navigation__secondary__item">
# <a class="c-header-global__navigation__secondary__item__link" href="https://www.skechers.com/wishlist/" id="utility-wishlist">
# <svg aria-hidden="true" class="c-icon--wishlist">
# <use class="" xlink:href="https://www.skechers.com/on/demandware.static/Sites-USSkechers-Site/-/default/dw1a66e44c/svg/symbols.svg#svg-wishlist"></use>
# </svg>
# Wishlist
# </a>
# </div>
# <div class="c-header-global__navigation__secondary__item">
# <svg aria-hidden="true" class="c-icon--help mr-1">
# <use class="" xlink:href="https://www.skechers.com/on/demandware.static/Sites-USSkechers-Site/-/default/dw1a66e44c/svg/symbols.svg#svg-mystore"></use>
# </svg>
# <form class="bopis-header-container" data-geolocation-url="https://www.skechers.com/on/demandware.store/Sites-USSkechers-Site/en_US/Geolocation-SetGeolocation?fromAction=" data-storeinsession="https://www.skechers.com/on/demandware.store/Sites-USSkechers-Site/en_US/Product-StoreInSession">
# <a class="c-header-global__navigation__secondary__item__link change-store-header" data-action-url="https://www.skechers.com/on/demandware.store/Sites-USSkechers-Site/en_US/Stores-InventorySearch?showMap=false&amp;horizontalView=true&amp;isForm=true" data-ats-action-url="https://www.skechers.com/on/demandware.store/Sites-USSkechers-Site/en_US/Stores-getAtsValue" data-modal-close-text="Close" data-modal-title-text="Free In-Store Pickup" data-postal="" data-set-location-label="Set Location" href="#" id="utility-bopis">
# <span class="c-header-global__navigation__secondary__item__link">
# Set My Store
# </span>
# </a>
# </form>
# </div>
# <div class="c-header-global__navigation__secondary__item">
# <a class="c-header-global__navigation__secondary__item__link USA | USD" data-target="#countrySelectFlyout" data-toggle="flyout" href="https://www.skechers.com/countries.html" id="utility-country">
# <svg aria-hidden="true" class="c-icon--locale">
# <title class="sr-only" font-size="0" x="50%" y="50%">United States</title>
# <use class="" xlink:href="https://www.skechers.com/on/demandware.static/Sites-USSkechers-Site/-/default/dw1a66e44c/svg/symbols.svg#svg-usa"></use>
# <text class="sr-only" font-size="0" x="50%" y="50%">United States</text>
# </svg>
# USA | USD
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </nav>
# <nav class="c-header-global__navigation__primary js-header-nav-primary" data-rfk-server-side="true" id="nav-primary">
# <div class="header container-fluid">
# <div class="c-header-global__navigation__primary__navbar row">
# <div class="col-12">
# <div class="navbar-header d-flex justify-content-between align-items-center">
# <div class="d-flex col px-0 position-static">
# <div class="c-navigation-global__backdrop"></div>
# <a class="logo-home align-self-center" href="https://www.skechers.com/" id="logo-home" title="Skechers Home">
# <svg aria-hidden="true" class="c-icon--logo">
# <title class="sr-only" font-size="0" x="50%" y="50%">Skechers</title>
# <use class="" xlink:href="https://www.skechers.com/on/demandware.static/Sites-USSkechers-Site/-/default/dw1a66e44c/svg/symbols.svg#svg-logo"></use>
# <text class="sr-only" font-size="0" x="50%" y="50%">Skechers</text>
# </svg>
# </a>
# <div class="c-navigation-global main-menu navbar-toggleable-md navbar-toggleable-sm menu-toggleable-right multilevel-dropdown d-none d-lg-block loyalty-nav-enabled" id="sg-navbar-collapse">
# <nav class="navbar navbar-expand-lg bg-inverse" id="navbar-primary">
# <div class="close-menu clearfix d-lg-none c-navigation-global__close-menu">
# <div class="back pull-left">
# <button aria-label="Back to previous menu" class="c-navigation-global__close-menu__back" role="button">
# <span class="caret-left"></span>
# Back
# </button>
# </div>
# <div class="close-button pull-right">
# <button aria-label="Close Menu" class="c-navigation-global__close-menu__btn" role="button">
# <span aria-hidden="true"><svg aria-hidden="true" class="c-navigation-global__close-menu__btn__icon">
# <use class="" xlink:href="https://www.skechers.com/on/demandware.static/Sites-USSkechers-Site/-/default/dw1a66e44c/svg/symbols.svg#svg-close"></use>
# </svg></span>
# </button>
# </div>
# </div>
# <div class="menu-group" role="navigation">
# <ul class="nav navbar-nav c-navigation-global__navbar" role="menu">
# <li class="c-navigation-global__item nav-item js-global-nav-item dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="c-navigation-global__item__link nav-link dropdown-toggle" data-toggle="dropdown" href="/women/" id="women" role="button" style="" tabindex="0">
# Women
# </a>
# <div aria-hidden="true" aria-label="women" class="dropdown-menu c-megamenu" role="menu">
# <div class="c-megamenu__inner">
# <div class="dropdown-item s-megamenu s-megamenu--alt-l1-content c-megamenu__dropdown-item c-megamenu__dropdown-item--alt-l1-content">
# <ul>
# <li><a class="dropdown-link c-megamenu_sub-item_link" href="https://www.skechers.com/women/shoes/" id="womens-shop-all" role="menuitem" style="" tabindex="0">Shop All Women's</a></li>
# <li><a class="dropdown-link c-megamenu_sub-item_link" href="https://www.skechers.com/new-arrivals/women/" id="womens-new-arrivals" role="menuitem" style="" tabindex="0">New Arrivals</a></li>
# <li><a class="dropdown-link c-megamenu_sub-item_link" href="https://www.skechers.com/commercials/" id="womens-commercials" role="menuitem" style="" tabindex="0">Commercials</a></li>
# <li><a class="dropdown-link c-megamenu_sub-item_link" href="https://www.skechers.com/best-sellers/women/" id="womens-best-sellers" role="menuitem" style="" tabindex="0">Best Sellers</a></li>
# <li><a class="dropdown-link c-megamenu_sub-item_link" href="https://www.skechers.com/technologies/collections/snoop-dogg/?prefn1=gender&amp;prefv1=W" id="womens-snoop-plp" role="menuitem" style="" tabindex="0">Snoop Dogg Styles</a></li>
# <li><a class="dropdown-link c-megamenu_sub-item_link" href="https://www.skechers.com/sale/?prefn1=gender&amp;prefv1=W" id="womens-sale" role="menuitem" style="color:#990000" tabindex="0">Women's Sale</a></li>
# <ul>
# </ul>
# </ul>
# </div>
# <ul class="c-megamenu__dropdown-item c-megamenu__dropdown-item--sub-children dropdown-item" style="max-height: 520px;">
# <li class="dropdown c-megamenu__sub-child nav-item">
# <a aria-expanded="false" aria-haspopup="true" class="dropdown-link dropdown-toggle c-megamenu__sub-child__link nav-link p-lg-0" data-toggle="dropdown" href="/women/shoes/" id="women-shoes" role="button" style="" tabindex="0">
# Shoes
# </a>
# <ul aria-hidden="true" aria-label="women-shoes" class="dropdown-menu c-megamenu__sub-item c-megamenu__sub-item--l2" role="menu">
# <li class="dropdown-item c-megamenu__sub-item__inner">
# <ul class="c-megamenu__sub-item__links">
# <li class="c-megamenu__sub-item__link__wrapper">
# <a class="dropdown-link c-megamenu__sub-item__link" href="/women/shoes/athletic-sneakers/" id="women-shoes-athletic-sneakers" role="menuitem" style="" tabindex="0">Athletic Sneakers
# </a>
# </li>
# <li class="c-megamenu__sub-item__link__wrapper">
# <a class="dropdown-link c-megamenu__sub-item__link" href="/women/shoes/casual-sneakers/" id="women-shoes-casual-sneakers" role="menuitem" style="" tabindex="0">Casual Sneakers
# </a>
# </li>
# <li class="c-megamenu__sub-item__link__wrapper">
# <a class="dropdown-link c-megamenu__sub-item__link" href="/women/shoes/boots/" id="women-shoes-boots" role="menuitem" style="" tabindex="0">Boots
# </a>
# </li>
# <li class="c-megamenu__sub-item__link__wrapper">
# <a class="dropdown-link c-megamenu__sub-item__link" href="/women/shoes/flats/" id="women-shoes-flats" role="menuitem" style="" tabindex="0">Flats
# </a>
# </li>
# <li class="c-megamenu__sub-item__link__wrapper">
# <a class="dropdown-link c-megamenu__sub-item__link" href="/women/shoes/sandals/" id="women-shoes-sandals" role="menuitem" style="" tabindex="0">Sandals
# </a>
# </li>
# <li class="c-megamenu__sub-item__link__wrapper">
# <a class="dropdown-link c-megamenu__sub-item__link" href="/women/shoes/hands-free-slip-ins/" id="women-shoes-slip-ins" role="menuitem" style="" tabindex="0">Hands Free Slip-ins
# </a>
# </li>
# <li class="c-megamenu__sub-item__link__wrapper">
# <a class="dropdown-link c-megamenu__sub-item__link" href="/women/shoes/slip-ons/" id="women-shoes-slip-ons" role="menuitem" style="" tabindex="0">Slip-Ons
# </a>
# </li>
# <li class="c-megamenu__sub-item__link__wrapper">
# <a class="dropdown-link c-megamenu__sub-item__link" href="/women/shoes/lace-up/" id="womens-shoes-lace-up" role="menuitem" style="" tabindex="0">Lace Up
# </a>
# </li>
# <li class="c-megamenu__sub-item__link__wrapper">
# <a class="dropdown-link c-megamenu__sub-item__link" href="/women/shoes/wedges/" id="women-shoes-wedges" role="menuitem" style="" tabindex="0">Wedges
# </a>
# </li>
# <li class="c-megamenu__sub-item__link__wrapper">
# <a class="dropdown-link c-megamenu__sub-item__link" href="/women/shoes/boat-shoes/" id="women-shoes-boat-shoes" role="menuitem" style="" tabindex="0">Boat Shoes
# </a>
# </li>
# <li class="c-megamenu__sub-item__link__wrapper">
# <a class="dropdown-link c-megamenu__sub-item__link" href="/women/shoes/slippers/" id="womens-slippers" role="menuitem" style="" tabindex="0">Slippers
# </a>
# </li>
# <li class="c-megamenu__sub-item__link__wrapper">
# <a class="dropdown-link c-megamenu__sub-item__link" href="/women/shoes/work-safety/" id="collections-work-safety-womens" role="menuitem" style="" tabindex="0">Work &amp; Safety
# </a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="dropdown c-megamenu__sub-child nav-item">
# <a aria-expanded="false" aria-haspopup="true" class="dropdown-link dropdown-toggle c-megamenu__sub-child__link nav-link p-lg-0" data-toggle="dropdown" href="https://www.skechers.com/women/shoes/?prefn1=width&amp;prefv1=Wide%7CNarrow" id="women-shop-by-width" role="button" style="" tabindex="0">
# Shop by Width
# </a>
# <ul aria-hidden="true" aria-label="women-shop-by-width" class="dropdown-menu c-megamenu__sub-item c-megamenu__sub-item--l2" role="menu">
# <li class="dropdown-item c-megamenu__sub-item__inner">
# <ul class="c-megamenu__sub-item__links">
# <li class="c-megamenu__sub-item__link__wrapper">
# <a class="dropdown-link c-megamenu__sub-item__link" href="https://www.skechers.com/women/shoes/?prefn1=width&amp;prefv1=Wide" id="women-shop-by-fit-wide" role="menuitem" style="" tabindex="0">Wide
# </a>
# </li>
# <li class="c-megamenu__sub-item__link__wrapper">
# <a class="dropdown-link c-megamenu__sub-item__link" href="https://www.skechers.com/women/shoes/?prefn1=width&amp;prefv1=Narrow" id="women-shop-by-fit-narrow" role="menuitem" style="" tabindex="0">Narrow
# </a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="dropdown c-megamenu__sub-child nav-item">
# <a aria-expanded="false" aria-haspopup="true" class="dropdown-link dropdown-toggle c-megamenu__sub-child__link nav-link p-lg-0" data-toggle="dropdown" href="/women/shop-by-activity/" id="women-shop-by-activity" role="button" style="" tabindex="0">
# Shop by Activity
# </a>
# <ul aria-hidden="true" aria-label="women-shop-by-activity" class="dropdown-menu c-megamenu__sub-item c-megamenu__sub-item--l2" role="menu">
# <li class="dropdown-item c-megamenu__sub-item__inner">
# <ul class="c-megamenu__sub-item__links">
# <li class="c-megamenu__sub-item__link__wrapper">
# <a class="dropdown-link c-megamenu__sub-item__link" href="/women/shop-by-activity/golf/" id="women-shop-by-activity-golf" role="menuitem" style="" tabindex="0">Golf
# </a>
# </li>
# <li class="c-megamenu__sub-item__link__wrapper">
# <a class="dropdown-link c-megamenu__sub-item__link" href="/women/shop-by-activity/running/" id="women-shop-by-activity-running" role="menuitem" style="" tabindex="0">Running
# </a>
# </li>
# <li class="c-megamenu__sub-item__link__wrapper">
# <a class="dropdown-link c-megamenu__sub-item__link" href="/women/shop-by-activity/trail-hiking/" id="women-shop-by-activity-trail" role="menuitem" style="" tabindex="0">Trail &amp; Hiking
# </a>
# </li>
# <li class="c-megamenu__sub-item__link__wrapper">
# <a class="dropdown-link c-megamenu__sub-item__link" href="/women/shop-by-activity/training/" id="women-shop-by-activity-training" role="menuitem" style="" tabindex="0">Training
# </a>
# </li>
# <li class="c-megamenu__sub-item__link__wrapper">
# <a class="dropdown-link c-megamenu__sub-item__link" href="/women/shop-by-activity/walking/" id="women-shop-by-activity-walking" role="menuitem" style="" tabindex="0">Walking
# </a>
# </li>
# <li class="c-megamenu__sub-item__link__wrapper">
# <a class="dropdown-link c-megamenu__sub-item__link" href="https://www.skechers.com/technologies/collections/pickleball/?prefn1=gender&amp;prefv1=W%7CU" id="women-shop-by-activity-pickleball" role="menuitem" style="" tabindex="0">Pickleball
# </a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="c-megamenu__sub-child nav-item s-megamenu s-megamenu--alt-l2-content">
# <ul>
# <li class="dropdown">
# <span class="dropdown-link dropdown-toggle" data-toggle="dropdown">
# Comfort Technologies
# </span>
# <ul class="dropdown-menu">
# <li><a href="https://www.skechers.com/technologies/comfort-technologies/air-cooled-memory-foam/?prefn1=gender&amp;prefv1=W" id="comfort-aircooled-memory-foam-womens">Air Cooled Memory Foam</a></li>
# <li><a href="https://www.skechers.com/technologies/collections/womens/arch-fit/" id="comfort-arch-fit-womens">Arch Fit</a></li>
# <li><a href="https://www.skechers.com/technologies/comfort-technologies/glide-step/?prefn1=gender&amp;prefv1=W" id="comfort-glide-step-womens">Glide Step </a></li>
# <li><a href="https://www.skechers.com/technologies/comfort-technologies/goga-mat/?prefn1=gender&amp;prefv1=W" id="comfort-gogamat-womens">Goga Mat</a></li>
# <li><a href="https://www.skechers.com/technologies/comfort-technologies/slip-ins/?prefn1=gender&amp;prefv1=W" id="comfort-slipins-womens">Hands Free Slip-ins</a></li>
# <li><a href="https://www.skechers.com/technologies/comfort-technologies/hyper-burst/?prefn1=gender&amp;prefv1=W" id="comfort-hyperburst-womens">Hyperburst</a></li>
# <li><a href="https://www.skechers.com/technologies/comfort-technologies/luxe-foam/?prefn1=gender&amp;prefv1=W" id="comfort-luxefoam-womens">Luxe Foam</a></li>
# <li><a href="https://www.skechers.com/technologies/comfort-technologies/massage-fit/?prefn1=gender&amp;prefv1=W" id="comfort-massage-fit-womens">Massage Fit</a></li>
# <li><a href="https://www.skechers.com/technologies/collections/womens/max-cushioning/" id="comfort-max-cushioning-womens">Max Cushioning</a></li>
# <li><a href="https://www.skechers.com/technologies/collections/womens/relaxed-fit/" id="comfort-relaxed-fit-womens">Relaxed Fit</a></li>
# <li><a href="https://www.skechers.com/technologies/comfort-technologies/skech-air/?prefn1=gender&amp;prefv1=W" id="comfort-skech-air-womens">Skech Air</a></li>
# <li><a href="https://www.skechers.com/technologies/collections/womens/stretch-fit/" id="comfort-stretch-fit-womens">Stretch Fit</a></li>
# <li><a href="https://www.skechers.com/technologies/comfort-technologies/twist-fit/?prefn1=gender&amp;prefv1=W" id="comfort-twist-fit-womens">Twist Fit</a></li>
# <li><a href="https://www.skechers.com/technologies/comfort-technologies/ultra-go/?prefn1=gender&amp;prefv1=W" id="comfort-ultrago-womens">Ultra Go</a></li>
# <li><a href="https://www.skechers.com/technologies/comfort-technologies/workout-walker/?prefn1=gender&amp;prefv1=W" id="comfort-workout-walker-womens">Workout Walker</a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="c-megamenu__sub-child nav-item s-megamenu s-megamenu--alt-l2-content">
# <ul>
# <li class="dropdown">
# <span class="dropdown-link dropdown-toggle" data-toggle="dropdown">
# Collections
# </span>
# <ul class="dropdown-menu">
# <li><a href="https://www.skechers.com/technologies/collections/bobs/?prefn1=gender&amp;prefv1=W" id="collections-bobs-for-dogs">BOBS</a></li>
# <li><a href="https://www.skechers.com/technologies/collections/cali/" id="collections-cali-womens">Cali</a></li>
# <li><a href="https://www.skechers.com/technologies/collections/court-classics/?prefn1=gender&amp;prefv1=W" id="collections-court-classics-womens">Court &amp; Classics</a></li>
# <li><a href="https://www.skechers.com/technologies/collections/dlites/" id="collections-dlites-womens">D'Lites</a></li>
# <li><a href="https://www.skechers.com/technologies/collections/womens/foamies/" id="collections-foamies-womens">Foamies</a></li>
# <li><a href="https://www.skechers.com/technologies/collections/go-run/?prefn1=gender&amp;prefv1=W" id="collections-go-run-womens">GO RUN</a></li>
# <li><a href="https://www.skechers.com/technologies/collections/womens/go-walk/" id="collections-go-walk-womens">GO WALK</a></li>
# <li><a href="https://www.skechers.com/technologies/collections/womens/mark-nason/" id="collections-mark-nason-women">Mark Nason</a></li>
# <li><a href="https://www.skechers.com/technologies/collections/womens/modern-comfort/" id="collections-modern-comfort-womens">Modern Comfort</a></li>
# <li><a href="https://www.skechers.com/technologies/collections/our-planet-matters/?prefn1=gender&amp;prefv1=W" id="collections-bobs-earth-womens">Our Planet Matters</a></li>
# <li><a href="https://www.skechers.com/technologies/collections/pickleball/?prefn1=gender&amp;prefv1=W" id="collections-picklepall-womens">Pickleball</a></li>
# <li><a href="https://www.skechers.com/technologies/collections/womens/sport/" id="collections-sport-women">Sport</a></li>
# <li><a href="https://www.skechers.com/technologies/collections/womens/skechers-street/" id="collections-skechers-street-women">SKECHERS Street™</a></li>
# <li><a href="https://www.skechers.com/technologies/collections/unos/?prefn1=gender&amp;prefv1=W" id="collections-uno-womens">UNOs</a></li>
# <li><a href="https://www.skechers.com/women/shoes/work-safety/" id="collections-work-safety-womens">Work &amp; Safety</a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="c-megamenu__sub-child nav-item s-megamenu s-megamenu--alt-l2-content">
# <ul>
# <li class="dropdown">
# <span class="dropdown-link dropdown-toggle" data-toggle="dropdown">
# Collaborations
# </span>
# <ul class="dropdown-menu">
# <li><a href="https://www.skechers.com/collaborations/martha-stewart/martha-stewart-styles/" id="women-collab-martha">Martha Stewart</a></li>
# <li><a href="https://www.skechers.com/technologies/collections/snoop-dogg/" id="women-collab-snoop">Snoop Dogg</a></li>
# <li><a href="https://www.skechers.com/collaborations/ricardo-cavolo/ricardo-cavolo-collection/" id="women-collab-cavolo">Ricardo Cavolo</a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="c-megamenu__sub-child nav-item s-megamenu s-megamenu--alt-l2-content">
# <ul>
# <li class="dropdown">
# <a class="dropdown-link dropdown-toggle" data-toggle="dropdown" href="https://www.skechers.com/clothing/womens/">
# Clothing &amp; Accessories
# </a>
# <ul class="dropdown-menu">
# <li><a href="https://www.skechers.com/clothing/womens/tops/" id="clothing-accessories-womens-tops">Tops</a></li>
# <li><a href="https://www.skechers.com/clothing/womens/bottoms/" id="clothing-accessories-womens-bottoms">Bottoms</a></li>
# <li><a href="https://www.skechers.com/clothing/accessories/bags/?prefn1=gender&amp;prefv1=W%7CU" id="clothing-accessories-womens-bags">Bags</a></li>
# <li><a href="https://www.skechers.com/clothing/accessories/hats/?prefn1=gender&amp;prefv1=W%7CU" id="clothing-accessories-womens-hats">Hats</a></li>
# <li><a href="https://www.skechers.com/clothing/accessories/socks/?prefn1=gender&amp;prefv1=W%7CU" id="clothing-accessories-womens-socks">Socks</a></li>
# </ul>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="c-navigation-global__item nav-item js-global-nav-item dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="c-navigation-global__item__link nav-link dropdown-toggle" data-toggle="dropdown" href="/men/" id="men" role="button" style="" tabindex="0">
# Men
# </a>
# <div aria-hidden="true" aria-label="men" class="dropdown-menu c-megamenu" role="menu">
# <div class="c-megamenu__inner">
# <div class="dropdown-item s-megamenu s-megamenu--alt-l1-content c-megamenu__dropdown-item c-megamenu__dropdown-item--alt-l1-content">
# <ul>
# <li><a class="dropdown-link c-megamenu_sub-item_link" href="https://www.skechers.com/men/shoes/" id="men-shop-all" role="menuitem" style="" tabindex="0">Shop All Men's</a></li>
# <li><a class="dropdown-link c-megamenu_sub-item_link" href="https://www.skechers.com/new-arrivals/men/" id="mens-new-arrivals" role="menuitem" style="" tabindex="0">New Arrivals</a></li>
# <li><a class="dropdown-link c-megamenu_sub-item_link" href="https://www.skechers.com/commercials/" id="mens-commercials" role="menuitem" style="" tabindex="0">Commercials</a></li>
# <li><a class="dropdown-link c-megamenu_sub-item_link" href="https://www.skechers.com/best-sellers/men/" id="mens-best-sellers" role="menuitem" style="" tabindex="0">Best Sellers</a></li>
# <li><a class="dropdown-link c-megamenu_sub-item_link" href="https://www.skechers.com/technologies/collections/snoop-dogg/?prefn1=gender&amp;prefv1=M" id="mens-snoop-plp" role="menuitem" style="" tabindex="0">Snoop Dogg Styles</a></li>
# <li><a class="dropdown-link c-megamenu_sub-item_link" href="https://www.skechers.com/sale/?prefn1=gender&amp;prefv1=M" id="mens-sale" role="menuitem" style="color:#990000" tabindex="0">Men's Sale</a></li>
# </ul>
# </div>
# <ul class="c-megamenu__dropdown-item c-megamenu__dropdown-item--sub-children dropdown-item" style="max-height: 520px;">
# <li class="dropdown c-megamenu__sub-child nav-item">
# <a aria-expanded="false" aria-haspopup="true" class="dropdown-link dropdown-toggle c-megamenu__sub-child__link nav-link p-lg-0" data-toggle="dropdown" href="/men/shoes/" id="men-shoes" role="button" style="" tabindex="0">
# Shoes
# </a>
# <ul aria-hidden="true" aria-label="men-shoes" class="dropdown-menu c-megamenu__sub-item c-megamenu__sub-item--l2" role="menu">
# <li class="dropdown-item c-megamenu__sub-item__inner">
# <ul class="c-megamenu__sub-item__links">
# <li class="c-megamenu__sub-item__link__wrapper">
# <a class="dropdown-link c-megamenu__sub-item__link" href="/men/shoes/athletic-sneakers/" id="men-shoes-athletic-sneakers" role="menuitem" style="" tabindex="0">Athletic Sneakers
# </a>
# </li>
# <li class="c-megamenu__sub-item__link__wrapper">
# <a class="dropdown-link c-megamenu__sub-item__link" href="/men/shoes/casual-sneakers/" id="men-shoes-casual-sneakers" role="menuitem" style="" tabindex="0">Casual Sneakers
# </a>
# </li>
# <li class="c-megamenu__sub-item__link__wrapper">
# <a class="dropdown-link c-megamenu__sub-item__link" href="/men/shoes/boat-shoes/" id="men-shoes-boat-shoes" role="menuitem" style="" tabindex="0">Boat Shoes
# </a>
# </li>
# <li class="c-megamenu__sub-item__link__wrapper">
# <a class="dropdown-link c-megamenu__sub-item__link" href="/men/shoes/boots/" id="men-shoes-boots" role="menuitem" style="" tabindex="0">Boots
# </a>
# </li>
# <li class="c-megamenu__sub-item__link__wrapper">
# <a class="dropdown-link c-megamenu__sub-item__link" href="/men/shoes/hands-free-slip-ins/" id="men-shoes-slip-ins" role="menuitem" style="" tabindex="0">Hands Free Slip-ins
# </a>
# </li>
# <li class="c-megamenu__sub-item__link__wrapper">
# <a class="dropdown-link c-megamenu__sub-item__link" href="/men/shoes/slip-ons/" id="men-shoes-slip-ons" role="menuitem" style="" tabindex="0">Slip-Ons
# </a>
# </li>
# <li class="c-megamenu__sub-item__link__wrapper">
# <a class="dropdown-link c-megamenu__sub-item__link" href="/men/shoes/lace-up-oxfords/" id="men-shoes-lace-up-oxfords" role="menuitem" style="" tabindex="0">Lace Up Oxfords
# </a>
# </li>
# <li class="c-megamenu__sub-item__link__wrapper">
# <a class="dropdown-link c-megamenu__sub-item__link" href="/men/shoes/sandals/" id="men-shoes-sandals" role="menuitem" style="" tabindex="0">Sandals
# </a>
# </li>
# <li class="c-megamenu__sub-item__link__wrapper">
# <a class="dropdown-link c-megamenu__sub-item__link" href="/men/shoes/slippers/" id="men-slippers" role="menuitem" style="" tabindex="0">Slippers
# </a>
# </li>
# <li class="c-megamenu__sub-item__link__wrapper">
# <a class="dropdown-link c-megamenu__sub-item__link" href="/men/shoes/work-safety/" id="collections-work-safety-mens" role="menuitem" style="" tabindex="0">Work &amp; Safety
# </a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="dropdown c-megamenu__sub-child nav-item">
# <a aria-expanded="false" aria-haspopup="true" class="dropdown-link dropdown-toggle c-megamenu__sub-child__link nav-link p-lg-0" data-toggle="dropdown" href="https://www.skechers.com/men/shoes/?prefn1=width&amp;prefv1=Wide%7CExtra%20Wide%7CNarrow" id="men-shop-by-width" role="button" style="" tabindex="0">
# Shop by Width
# </a>
# <ul aria-hidden="true" aria-label="men-shop-by-width" class="dropdown-menu c-megamenu__sub-item c-megamenu__sub-item--l2" role="menu">
# <li class="dropdown-item c-megamenu__sub-item__inner">
# <ul class="c-megamenu__sub-item__links">
# <li class="c-megamenu__sub-item__link__wrapper">
# <a class="dropdown-link c-megamenu__sub-item__link" href="https://www.skechers.com/men/shoes/?prefn1=width&amp;prefv1=Wide" id="men-shop-by-fit-wide" role="menuitem" style="" tabindex="0">Wide
# </a>
# </li>
# <li class="c-megamenu__sub-item__link__wrapper">
# <a class="dropdown-link c-megamenu__sub-item__link" href="https://www.skechers.com/men/shoes/?prefn1=width&amp;prefv1=Extra%20Wide" id="men-shop-by-fit-extra-wide" role="menuitem" style="" tabindex="0">Extra-Wide
# </a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# ...
# <div class="s-country-selector__country">
# <div class="flag-rendered-padding">
# <a class="s-country-selector__country-name" href="https://www.skechers.es/">Spain</a>
# </div>
# </div>
# <div class="s-country-selector__country-links flag-rendered-padding">
# <a href="https://www.skechers.es/">España</a>
# </div>
# </div>
# <div class="col-12 col-lg-3 s-country-selector__country-wrapper s-country-selector__country-wrapper--ecommerce">
# <div class="s-country-selector__country">
# <div class="flag-rendered-padding">
# <a class="s-country-selector__country-name" href="http://www.skechers.se/">Sweden</a>
# </div>
# </div>
# <div class="s-country-selector__country-links flag-rendered-padding">
# <a href="http://www.skechers.se/">Sverige</a>
# </div>
# </div>
# <div class="col-12 col-lg-3 s-country-selector__country-wrapper s-country-selector__country-wrapper--ecommerce">
# <div class="s-country-selector__country">
# <div class="flag-rendered-padding">
# <a class="s-country-selector__country-name" href="https://www.skechers.ch/">Switzerland</a>
# </div>
# </div>
# <div class="s-country-selector__country-links flag-rendered-padding">
# <a href="https://www.skechers.ch/">Schweiz</a>
# </div>
# </div>
# <div class="col-12 col-lg-3 s-country-selector__country-wrapper s-country-selector__country-wrapper--ecommerce">
# <div class="s-country-selector__country">
# <div class="flag-rendered-padding">
# <a class="s-country-selector__country-name" href="http://www.skechers.com.tr/">Turkey</a>
# </div>
# </div>
# <div class="s-country-selector__country-links flag-rendered-padding">
# <a href="http://www.skechers.com.tr/">Türkiye</a>
# </div>
# </div>
# <div class="col-12 col-lg-3 s-country-selector__country-wrapper s-country-selector__country-wrapper--ecommerce">
# <div class="s-country-selector__country">
# <div class="flag-rendered-padding">
# <a class="s-country-selector__country-name" href="https://www.skechers.co.uk/">United Kingdom</a>
# </div>
# </div>
# <div class="s-country-selector__country-links flag-rendered-padding">
# </div>
# </div>
# </div>
# </div>
# <div class="s-country-selector__continent collapsible-md">
# <div class="s-country-selector__continent-title title" data-target="#country-selector-2" data-toggle="collapse">North and South America</div>
# <div class="row content collapse" id="country-selector-2">
# <div class="col-12 col-lg-3 s-country-selector__country-wrapper">
# <div class="s-country-selector__country">
# <div class="flag-rendered-padding">
# <a class="s-country-selector__country-name" href="http://www.br.skechers.com/pt-br/">Brazil</a>
# </div>
# </div>
# <div class="s-country-selector__country-links flag-rendered-padding">
# </div>
# </div>
# <div class="col-12 col-lg-3 s-country-selector__country-wrapper s-country-selector__country-wrapper--ecommerce">
# <div class="s-country-selector__country">
# <div class="flag-rendered-padding">
# <a class="s-country-selector__country-name" href="https://www.skechers.ca/on/demandware.store/Sites-CASkechers-Site/en_CA/GeoRedirect-Redirect?currentSiteId=USSkechers&amp;countrycode=CA">Canada</a>
# </div>
# </div>
# <div class="s-country-selector__country-links flag-rendered-padding">
# <p><a href="https://www.skechers.ca/on/demandware.store/Sites-CASkechers-Site/en_CA/GeoRedirect-Redirect?currentSiteId=USSkechers&amp;countrycode=CA">Canada (fr)</a></p>
# </div>
# </div>
# <div class="col-12 col-lg-3 s-country-selector__country-wrapper s-country-selector__country-wrapper--ecommerce">
# <div class="s-country-selector__country">
# <div class="flag-rendered-padding">
# <a class="s-country-selector__country-name" href="http://www.skechers-chile.cl/">Chile</a>
# </div>
# </div>
# <div class="s-country-selector__country-links flag-rendered-padding">
# </div>
# </div>
# <div class="col-12 col-lg-3 s-country-selector__country-wrapper">
# <div class="s-country-selector__country">
# <div class="flag-rendered-padding">
# <a class="s-country-selector__country-name" href="http://www.co.skechers.com/">Colombia</a>
# </div>
# </div>
# <div class="s-country-selector__country-links flag-rendered-padding">
# </div>
# </div>
# <div class="col-12 col-lg-3 s-country-selector__country-wrapper s-country-selector__country-wrapper--ecommerce">
# <div class="s-country-selector__country">
# <div class="flag-rendered-padding">
# <a class="s-country-selector__country-name" href="http://www.skechers.com.mx/">Mexico</a>
# </div>
# </div>
# <div class="s-country-selector__country-links flag-rendered-padding">
# </div>
# </div>
# <div class="col-12 col-lg-3 s-country-selector__country-wrapper">
# <div class="s-country-selector__country">
# <div class="flag-rendered-padding">
# <a class="s-country-selector__country-name" href="http://www.pa.skechers.com/">Panama</a>
# </div>
# </div>
# <div class="s-country-selector__country-links flag-rendered-padding">
# <a href="http://www.pa.skechers.com/">Panamá</a>
# </div>
# </div>
# <div class="col-12 col-lg-3 s-country-selector__country-wrapper">
# <div class="s-country-selector__country">
# <div class="flag-rendered-padding">
# <a class="s-country-selector__country-name" href="http://www.pe.skechers.com">Peru</a>
# </div>
# </div>
# <div class="s-country-selector__country-links flag-rendered-padding">
# <a href="http://www.pe.skechers.com/">Perú</a>
# </div>
# </div>
# <div class="col-12 col-lg-3 s-country-selector__country-wrapper s-country-selector__country-wrapper--ecommerce">
# <div class="s-country-selector__country">
# <div class="flag-rendered-padding">
# <a class="s-country-selector__country-name" href="https://www.skechers.com/on/demandware.store/Sites-USSkechers-Site/en_US/GeoRedirect-Redirect?currentSiteId=USSkechers&amp;countrycode=US">United States</a>
# </div>
# </div>
# <div class="s-country-selector__country-links flag-rendered-padding">
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </footer>
# <script>
#     window.addEventListener('load', (event) => {
#         const srfkScript = document.createElement('script');
#         srfkScript.setAttribute('type', 'text/javascript');
#         srfkScript.setAttribute('async', 'true');
#         srfkScript.setAttribute('src', 'https://skechers.rfk.skechers.com/api/init/1/init.js');
#         document.head.appendChild(srfkScript);
#     });
# </script>
# <script>
#     var rfk = window.rfk = window.rfk || [];
#     var rfkCountry = 'us';
#     var rfkLanguage = 'en';
#     var rfkDomain = 'www.skechers.com';
#     var rfkCurrency = 'usd';
#     var cartGetURL='https://www.skechers.com/on/demandware.store/Sites-USSkechers-Site/en_US/Cart-Get';
#     rfk.push({
#         "locale_country": rfkCountry,
#         "locale_language": rfkLanguage
#     });
#
#
#
# </script>
# <span class="optin-modal-get-url" data-url="https://www.skechers.com/on/demandware.store/Sites-USSkechers-Site/en_US/EmailSubscribe-OptinModalHTML"></span>
# </div>
# <div class="error-messaging"></div>
# <div class="modal-background"></div>
# <div id="otp-login-success" style="display: none;">
# <div class="site-alert-msg text-left alert-success otp-login-success-msg">
# <img class="success-check" src="https://www.skechers.com/on/demandware.static/Sites-USSkechers-Site/-/default/dw2af8d896/images/defaultSuccessCheck.svg"/>
# You have successfully logged in.
# </div>
# </div>
# <!--[if lt IE 10]>
# <script>
#     (function () {
#
#
#         /**
#          * Prevent default for links containing class `js-ignore-click`
#          * @param {Event} e
#          */
#         var clickListener = function (e) {
#             if (
#                 e &&
#                 e.target &&
#                 e.target.classList &&
#                 e.target.classList.contains('js-ignore-click')
#             ) {
#                 e.preventDefault();
#             }
#         }
#
#         /**
#          * Remove click listener then remove itself from `app:JsLoaded` listener.
#          */
#         var appJsLoadedListener = function () {
#             document.removeEventListener('click', clickListener)
#             document.removeEventListener('app:JsLoaded', appJsLoadedListener);
#         };
#
#         document.addEventListener('click', clickListener);
#         document.addEventListener('app:JsLoaded', appJsLoadedListener);
#     }());
# </script>
#
# <script>
#     document.addEventListener('DOMContentLoaded', function () {
#         var url = "https://www.skechers.com/on/demandware.store/Sites-USSkechers-Site/en_US/Geolocation-SetGeolocation?fromAction=Sites-USSkechers-Site";
#
#         // Send geolocation to SFCC
#         function success(position) {
#             var pid = $('.product-detail[data-pid]').data('pid');
#
#             $.ajax({
#                 url: url,
#                 method: 'GET',
#                 data: {
#                     latitude: position.coords.latitude,
#                     longitude: position.coords.longitude,
#                     pid: pid
#                 },
#                 success: function (data) {
#                     // run the header logic
#                     // Update the Class
#
#                     var $containerHeader = $('.js-global-header');
#
#                         $('body').trigger('instore:updateStoreHeader', {
#                             data: data,
#                             container: $containerHeader
#                         });
#
#
#
#                 },
#                 error: function (err) {
#                 }
#             });
#         }
#
#         // Sets an error flag so multiple geolocation requests aren't made
#         function error(err) {
#             var url = "https://www.skechers.com/on/demandware.store/Sites-USSkechers-Site/en_US/Geolocation-SetGeolocation?fromAction=Sites-USSkechers-Site";
#
#             $.ajax({
#                 url: url,
#                 method: 'GET',
#                 data: {
#                     error: 'true'
#                 },
#                 success: function (data) {
#                 },
#                 error: function (err) {
#                 }
#             })
#         }
#
#         navigator.geolocation.getCurrentPosition(success, error);
#     });
# </script>
#
#
#
# <script>
#     (function() {
#         window.dataLayer = window.dataLayer || [];
#
#
#
#         window.dataLayer.push({"event":"pageview","page":{"type":"home"},"user":{"id":"","loggedIn":false,"hashedemail":"","locale":"en_US"},"site":{"environment":"production"}});
#
#         window.dataLayer.push({"user":{"loggedIn":"false"}});
#
#
#     }());
# </script>
#
# <script>
#     (function() {
#         window.dataLayer = window.dataLayer || [];
#
#
#
#         window.dataLayer.push({"pageType":"home"});
#
#         window.dataLayer.push({"ecomm_pagetype":"home"});
#
#         window.dataLayer.push({"page":{"currencyCode":"USD","locale":"en_US","pageTitle":"SKECHERS Official Site | The Comfort Technology Company","pageType":"Home"}});
#
#
#     }());
# </script>
#
#
#
# <script>
#    vice= {
#         config: {
#             viceAccountId: 'skecherssecurity',
#             viceSiteId: 'skechers',
#             viceSectionId: ''
#         }
#     }
# </script>
# <script src='//assets.skechers.com/skccdn/vice_loader/skecherssecurity/skechers'></script>
#
#
#
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl+ '&gtm_auth=7lRL-CECKNSv2w3ulidcfw&gtm_preview=env-1&gtm_cookies_win=x';f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-TDRBQZ');</script>
#
#
#
#
# <script>//common/scripts.isml</script>
#
#
# <script defer type="text/javascript" src="https://www.skechers.com/on/demandware.static/Sites-USSkechers-Site/-/en_US/v1702916928659/js/main.js"></script>
# <script defer type="text/javascript" src="https://www.skechers.com/on/demandware.static/Sites-USSkechers-Site/-/en_US/v1702916928659/js/sfra.js"></script>
#
#     <script defer type="text/javascript" src="/on/demandware.static/Sites-USSkechers-Site/-/en_US/v1702916928659/js/login.js"
#
#         >
#     </script>
#
#
#
#
# <script>
# var CRL8_SITENAME = "skechers-9cenl4";
# window.loadCuralate = function () {
#     if (document.getElementById('js-load-curalate')) {
#         !function(){var e=window.crl8=window.crl8||{},n=!1,i=[];e.ready=function(e){n?e():i.push(e)},e.pixel=e.pixel||function(){e.pixel.q.push(arguments)},e.pixel.q=e.pixel.q||[];var t=window.document,o=t.createElement("script"),c=e.debug||-1!==t.location.search.indexOf("crl8-debug=true")?"js":"min.js";o.src=t.location.protocol+"//cdn.curalate.com/sites/"+CRL8_SITENAME+"/site/latest/site."+c,o.onload=function(){n=!0,i.forEach(function(e){e()})};var r=t.getElementsByTagName("script")[0];r.parentNode.insertBefore(o,r.nextSibling)}();
#     }
# };
# </script>
#
#
#
#
#
#
#
#
# <![endif]-->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-TDRBQZ&amp;gtm_auth=7lRL-CECKNSv2w3ulidcfw&amp;gtm_preview=env-1&amp;gtm_cookies_win=x" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <script>
# (function () {
# if (!window.additionalWebFonts) {
# return;
# }
# var loadWebFonts = function () {
# if (!window.WebFont) {
# setTimeout(loadWebFonts, 200);
# }
# window.WebFont.load({
# google: {
# families: window.additionalWebFonts
# }
# });
# };
# loadWebFonts();
# }());
# </script>
# <script type="text/javascript">//<!--
# /* <![CDATA[ */
# function trackPage() {
#     try{
#         var trackingUrl = "https://www.skechers.com/on/demandware.store/Sites-USSkechers-Site/en_US/__Analytics-Start";
#         var dwAnalytics = dw.__dwAnalytics.getTracker(trackingUrl);
#         if (typeof dw.ac == "undefined") {
#             dwAnalytics.trackPageView();
#         } else {
#             dw.ac.setDWAnalytics(dwAnalytics);
#         }
#     }catch(err) {};
# }
# /* ]]> */
# // -->
# </script>
# <script async="async" onload="trackPage()" src="/on/demandware.static/Sites-USSkechers-Site/-/en_US/v1702916928659/internal/jscript/dwanalytics-22.2.js" type="text/javascript"></script>
# <script async="async" src="/on/demandware.static/Sites-USSkechers-Site/-/en_US/v1702916928659/internal/jscript/dwac-21.7.js" type="text/javascript"></script>
# <script async="async" src="https://cdn.cquotient.com/js/v2/gretel.min.js" type="text/javascript"></script>
# <script type="text/javascript">//<!--
# /* <![CDATA[ */
# if (!window.dw) dw = {};
# dw.applepay = {"action":{"cancel":"https:\/\/www.skechers.com\/on\/demandware.store\/Sites-USSkechers-Site\/en_US\/__SYSTEM__ApplePay-Cancel","getRequest":"https:\/\/www.skechers.com\/on\/demandware.store\/Sites-USSkechers-Site\/en_US\/__SYSTEM__ApplePay-GetRequest","onshippingcontactselected":"https:\/\/www.skechers.com\/on\/demandware.store\/Sites-USSkechers-Site\/en_US\/__SYSTEM__ApplePay-ShippingContactSelected","onpaymentmethodselected":"https:\/\/www.skechers.com\/on\/demandware.store\/Sites-USSkechers-Site\/en_US\/__SYSTEM__ApplePay-PaymentMethodSelected","onvalidatemerchant":"https:\/\/www.skechers.com\/on\/demandware.store\/Sites-USSkechers-Site\/en_US\/__SYSTEM__ApplePay-ValidateMerchant","onpaymentauthorized":"https:\/\/www.skechers.com\/on\/demandware.store\/Sites-USSkechers-Site\/en_US\/__SYSTEM__ApplePay-PaymentAuthorized","prepareBasket":"https:\/\/www.skechers.com\/on\/demandware.store\/Sites-USSkechers-Site\/en_US\/__SYSTEM__ApplePay-PrepareBasket","onshippingmethodselected":"https:\/\/www.skechers.com\/on\/demandware.store\/Sites-USSkechers-Site\/en_US\/__SYSTEM__ApplePay-ShippingMethodSelected"},"inject":{"directives":[{"css":"dw-apple-pay-button","query":"ISAPPLEPAY","action":"replace","copy":true}]}};
# /* ]]> */
# // -->
# </script>
# <script async="true" src="/on/demandware.static/Sites-USSkechers-Site/-/en_US/v1702916928659/internal/jscript/applepay.js" type="text/javascript"></script>
# <script crossorigin="anonymous" data-cf-beacon='{"rayId":"83794d2ac8155505","b":1,"version":"2023.10.0","token":"01336904d56945a7b3c22658f2080458"}' defer="" integrity="sha512-euoFGowhlaLqXsPWQ48qSkBSCFs3DPRyiwVu3FjR96cMPx+Fr+gpWRhIafcHwqwCqWS42RZhIudOvEI+Ckf6MA==" src="https://static.cloudflareinsights.com/beacon.min.js/v84a3a4012de94ce1a686ba8c167c359c1696973893317"></script>
# </body></html>

# %%
  soup = BeautifulSoup(response.text, 'html.parser')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 soup = BeautifulSoup(response.text, 'html.parser')
#
# NameError: name 'BeautifulSoup' is not defined

# %%
 rows = soup.find_all('tr')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 rows = soup.find_all('tr')
#
# NameError: name 'soup' is not defined
